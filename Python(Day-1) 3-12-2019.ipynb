# %% [markdown]
# # introduction to python programming

# %% [markdown]
# # markdown

# %% [markdown]
# # markdown

# %% [markdown]
# ## markdown

# %%
"iam manideep"
# Out:
# 'iam manideep'

# %% [markdown]
# "i am manideep"

# %% [markdown]
# * "i am manideep"

# %% [markdown]
# * * "my name is manideep" * *

# %% [markdown]
# # manideep

# %% [markdown]
# - normal text
#  -- sub

# %%
# !{image}data:image/jpeg;base64,...
# Out:
# The command line is too long.

# %%
# !{image}(data:image/jpeg;base64,...)
# Out:
# The command line is too long.

# %% [markdown]
# ![image]data:image/jpeg;base64,...

# %% [markdown]
# ![image]https://www.google.com/imgres?imgurl=https%3A%2F%2Fwww.python.org%2Fstatic%2Fcommunity_logos%2Fpython-logo-master-v3-TM.png&imgrefurl=https%3A%2F%2Fwww.python.org%2Fcommunity%2Flogos%2F&docid=ZIk6oEy_LSc-sM&tbnid=OO5BXHlBkMORMM%3A&vet=10ahUKEwi148yS05jmAhUGOSsKHW2bBhUQMwh4KAAwAA..i&w=601&h=203&bih=789&biw=1440&q=python%20logo&ved=0ahUKEwi148yS05jmAhUGOSsKHW2bBhUQMwh4KAAwAA&iact=mrc&uact=8

# %% [markdown]
# ![image]data:image/jpeg;base64,...

# %% [markdown]
# ![imge]https://www.google.com/imgres?imgurl=https%3A%2F%2Fmpng.pngfly.com%2F20181115%2Fttc%2Fkisspng-programming-python-logo-programming-language-compu-data-analysis-course-st-hua-private-school-5bedd96a011543.8733544715423143460044.jpg&imgrefurl=https%3A%2F%2Fwww.pngfly.com%2Fpng-s9xd5f%2F&docid=_bcS5aWYOYdyTM&tbnid=WAyT2cKJA3gLJM%3A&vet=10ahUKEwif4cKW1ZjmAhWaV30KHaBVBy8QMwhyKAMwAw..i&w=900&h=360&bih=789&biw=1440&q=python%20logo%20png&ved=0ahUKEwif4cKW1ZjmAhWaV30KHaBVBy8QMwhyKAMwAw&iact=mrc&uact=8

# %% [markdown]
# ![image]https://www.python.org/static/community_logos/python-logo-master-v3-TM.png

# %% [markdown]
# ![image](https://www.google.com/imgres?imgurl=https%3A%2F%2Fwww.python.org%2Fstatic%2Fcommunity_logos%2Fpython-logo-master-v3-TM.png&imgrefurl=https%3A%2F%2Fwww.python.org%2Fcommunity%2Flogos%2F&docid=ZIk6oEy_LSc-sM&tbnid=OO5BXHlBkMORMM%3A&vet=10ahUKEwif4cKW1ZjmAhWaV30KHaBVBy8QMwhwKAEwAQ..i&w=601&h=203&bih=789&biw=1440&q=python%20logo%20png&ved=0ahUKEwif4cKW1ZjmAhWaV30KHaBVBy8QMwhwKAEwAQ&iact=mrc&uact=8)

# %% [markdown]
# ![image](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)

# %% [markdown]
# [drive](https://drive.google.com/drive/folders/1Kvp6UILYDVQEQ5riQz051yUqaWtWbQMh)

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
print("this is manideep")
# Out:
# hello world
# this is manideep

# %%
print("hello ",end="gitam")
print("hii")
# Out:
# hello gitamhii

# %%
print("this ",end="is")
print("manideep")
# Out:
# this ismanideep

# %%
a=3
b=2
c=a+b
print(c)
# Out:
# 5

# %%
a=1
a ,b ,c=1
a,b,c=1,2,3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-3923faaa19ac> in <module>
#       1 a=1
# ----> 2 a ,b ,c=1
#       3 a,b,c=1,2,3
#
# TypeError: cannot unpack non-iterable int object

# %%
a=b=c=1
d=a+b+c
print(d)
# Out:
# 3

# %%
a=10
a=b=c=10
a,b,c=10,20,30

# %%
a="manideep"
type(a)
# Out:
# str

# %%
id(a)
# Out:
# 64261680

# %%
a=10.5
type(a)
# Out:
# float

# %%
a=10
b=10
id(a)
id(b)
# Out:
# 1674627376

# %%
a=10
float(a)
# Out:
# 10.0

# %%
type(a)
# Out:
# int

# %%
name = "manideep"
age = "20"
a=print("my name is",name,"and my age is",age)
b=print("hello world")
print(a + b)
# Out:
# my name is manideep and my age is 20
# hello world
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-f3400192a7a4> in <module>
#       3 a=print("my name is",name,"and my age is",age)
#       4 b=print("hello world")
# ----> 5 print(a + b)
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
name="manideep"
age=20
a=input("my name is")
b=input("hello world")
c = a + b
print(c)
# Out:
# my name ismani
# hello worldd
# manid

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
c=a+b
print(c)
# Out:
# enter a number1
# enter a number3
# 4

# %%
a=input("enter something")
b=input("age")
c=a + b
print(c)
# Out:
# enter somethinghe is manideep
# age20 years old
# he is manideep20 years old

# %%
x=10
type(x)
# Out:
# int

# %%
x=1.5
type(x
)
# Out:
# float

# %%
x=1+2j
type(x)
# Out:
# complex

# %%
x=name
type(name)
# Out:
# str

# %%
x="true"
type(x)
# Out:
# str

# %%
x=float(12.5)
print(x)
# Out:
# 12.5

# %%
x=float(12)
print(x)
# Out:
# 12.0

# %%
x=complex(2,4)
print(x)
# Out:
# (2+4j)

# %%
x=complex(1,2)
y=complex(3,4)
print(x+y)
print(x-y)
print(x*y)
# Out:
# (4+6j)
# (-2-2j)
# (-5+10j)

# %%
a=True
type(a)
# Out:
# bool

# %%
a=False
type(a)
# Out:
# bool

# %%
s1="abc"
s2='abc'
print(s1)
s2
# Out:
# abc
# 'abc'

# %%
i=100
print(type(i))
# Out:
# <class 'int'>

# %%
s1=str(i)
print(s1)
type(s1)
# Out:
# 100
# str

# %%
f1=float(i)
print(f1)
type(f1)
# Out:
# 100.0
# float

# %%
s="100"
print(type(s))
# Out:
# <class 'str'>

# %%
f=10.5
type(f)
# Out:
# float

# %%
a=int(f)
type(a)
# Out:
# int

# %%
a="manideep"
len(a)
# Out:
# 8

# %%
len(s)
# Out:
# 3

# %%
len(s)
# Out:
# 3

# %%
len(str(f))
# Out:
# 4

# %% [markdown]
# # arthemtic operator

# %%
a=2
b=3
print(a+b)
print(a-b)
print(a*b)
print(b/a)
print(b%a)
print(b//a)
print(a**b)
# Out:
# 5
# -1
# 6
# 1.5
# 1
# 1
# 8

# %% [markdown]
# # membership operator

# %%
name="manideep"
print("a"in name)
# Out:
# True

# %% [markdown]
# # logical operators

# %%
x=4
y=5
print(x>=5 and x<10)
print(y>=5 and y<10 )
print(not(x))
# Out:
# False
# True
# False

# %% [markdown]
# # relational operators

# %%
a=2
b=4
print(a!=b)
# Out:
# True

# %% [markdown]
# # conditional statements
#  * * if
#  * * elif
#  * * else

# %%
a=int(input("enter the number"))
if a>0:
    print("a is positive")
elif a<0:
    print("a is negative")
else:
    print("doesnot exist")
# Out:
# enter the number-7
# a is negative

# %% [markdown]
# # **to check given number is even or odd
# # **to check given number is multiple of 3 and 5
# # **to find given number is leap year or not
# # **take 3 numbers as input and find the biggest number
# # **read the character if it is vowel prnt vowel otherwise consonent
